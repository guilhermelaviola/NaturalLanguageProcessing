# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/NaturalLanguageProcessing/blob/main/Class16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NLP Applications & Trends**
# When we think of Natural Language Processing (NLP), it's important to highlight its importance in human-machine interaction, its main applications—such as machine translation, virtual assistants, sentiment analysis, chatbots, text summarization, and fake news detection—and the trends shaping its future. As proposals for a more responsible future, we may mention smaller and more efficient models, the use of annotated datasets, and a greater focus on ethics and regulation. Furthermore, we may explore the state of the art in the use of generative models, techniques such as fine-tuning and prompt engineering, and presents the RAG (Retrieval Augmented Generation) method as a solution to increase the reliability of generated information, combining document retrieval with text generation based on reliable sources.

# %%
# Importing all the necessary libraries and resources:
import openai

# %% [markdown]
# ## **Example: Using Leading Generative Models**
#
# Generative models, such as GPT-4 and similar ones, are initially trained on vast datasets of text. After this basic training, they undergo a fine-tuning process, which specializes them to perform specific tasks according to the instructions they receive. This allows these models not only to generate text but also to retain the context of an interaction, enabling long and meaningful conversations with users. To implement ChatGPT in a program, the process is relatively simple with the help of the OpenAI library. The following code demonstrates how to start an instance of the model and configure it to complete a specific task.

# %%
# Inictializing the OpenAI instance:
openai_api = openai.OpenAI()

# Creating a class for the model:
class ChatGPT:
  def __init__(self, model_name='gpt-3.5-turbo'):
    self.model = model_name

  def generate_text(self, prompt):
    completion = openai_api.chat.completions.create(
        model=self.model,
        prompt=prompt,
        max_tokens=150
    )
    return completion.choices[0].text.strip()

# Using the model to generate a poem about recursion:
assistant = ChatGPT()
prompt = 'Explain the concept of recursion through a poem.'
print(assistant.generate_text(prompt))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipython-input-2330801808.py in <cell line: 0>()
#       1 # Inictializing the OpenAI instance:
# ----> 2 openai_api = openai.OpenAI()
#       3
#       4 # Creating a class for the model:
#       5 class ChatGPT:
#
# /usr/local/lib/python3.12/dist-packages/openai/_client.py in __init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     135             api_key = os.environ.get("OPENAI_API_KEY")
#     136         if api_key is None:
# --> 137             raise OpenAIError(
#     138                 "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     139             )
#
# ...

# %% [markdown]
# To use the OpenAI API, you'll need an API key. If you don't already have one, create a key on the [OpenAI website](https://platform.openai.com/account/api-keys).
#
# In Colab, add the key to the secrets manager under the "🔑" icon in the left panel. Give it the name `OPENAI_API_KEY`.

# %%
# Used to securely store your API key
from google.colab import userdata

# Set the OpenAI API key from Colab's secrets manager
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# Initialize the OpenAI instance with the API key
openai_api = openai.OpenAI(api_key=OPENAI_API_KEY)
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2175009898.py in <cell line: 0>()
#       3
#       4 # Set the OpenAI API key from Colab's secrets manager
# ----> 5 OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
#       6
#       7 # Initialize the OpenAI instance with the API key
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret OPENAI_API_KEY does not exist.

# %%
# Creating a class for the model:
class ChatGPT:
  def __init__(self, model_name='gpt-3.5-turbo'):
    self.model = model_name

  def generate_text(self, prompt):
    completion = openai_api.chat.completions.create(
        model=self.model,
        messages=[
            {"role": "user", "content": prompt}
        ],
        max_tokens=150
    )
    return completion.choices[0].message.content.strip()

# Using the model to generate a poem about recursion:
assistant = ChatGPT()
prompt = 'Explain the concept of recursion through a poem.'
print(assistant.generate_text(prompt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1630656596.py in <cell line: 0>()
#      17 assistant = ChatGPT()
#      18 prompt = 'Explain the concept of recursion through a poem.'
# ---> 19 print(assistant.generate_text(prompt))
#
# /tmp/ipython-input-1630656596.py in generate_text(self, prompt)
#       5
#       6   def generate_text(self, prompt):
# ----> 7     completion = openai_api.chat.completions.create(
#       8         model=self.model,
#       9         messages=[
#
# NameError: name 'openai_api' is not defined

# %%
response = assistant.generate_text('What is the sentiment behind this phrase? I love the movie!')
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-496656457.py in <cell line: 0>()
# ----> 1 response = assistant.generate_text('What is the sentiment behind this phrase? I love the movie!')
#       2 print(response)
#
# /tmp/ipython-input-1630656596.py in generate_text(self, prompt)
#       5
#       6   def generate_text(self, prompt):
# ----> 7     completion = openai_api.chat.completions.create(
#       8         model=self.model,
#       9         messages=[
#
# NameError: name 'openai_api' is not defined

# %%
# Let's suppose we recovered a document about Inter Milan's win over Borussia Dortmund in UCL:
news_context = "Late goals from Federico Dimarco and Andy Diouf helped Inter Milan defeat Borussia Dortmund in their final league phase fixture but last season's runners-up still failed to secure a direct spot in the Champions League last-16."

# Modle instructions:
prompt = 'You are an assistant who answers questions based on a context that you will receive. \
If the information in the context does not answer the question, say that the question cannot be answered based on your database.'

# Question about the event:
question = 'What team won the game?'
