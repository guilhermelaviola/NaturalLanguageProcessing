# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/NaturalLanguageProcessing/blob/main/Class13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Natural Language Pipelines & Batch Processing**
# Natural Language Processing (NLP) pipelines provide a structured and scalable way to process large volumes of text by organizing tasks such as tokenization, lemmatization, parsing, and named entity recognition into sequential steps. Tools like the SpaCy library simplify pipeline creation through pre-trained language models and customizable components, while batch processing improves efficiency, consistency, and resource utilization when handling large datasets. Cloud services such as AWS further support scalable NLP workflows by enabling data storage, batch execution, and result persistence using tools like S3, Lambda, and Redshift. A complete NLP pipeline typically involves data acquisition, cleaning and preparation, linguistic processing, and structured storage, all supported by proper logging and error handling to ensure robustness. Overall, well-designed NLP pipelines are essential for automating text analysis, maintaining reusable and maintainable code, and efficiently scaling to meet growing data demands.

# %%
! pip3 install spacy
! python3 -m spacy download en_core_web_sm # Download the English model 'en_core_web_sm'
! pip3 install wikipedia
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.0.1)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 100.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from wikipedia) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wikipedia) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->wikipedia) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=95a226d74adc4e4c6d12777d69cc1c865533e41e9de863d340e297000a50c8e4
#   Stored in directory: /root/.cache/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
# Importing all the necessary resources:
import spacy
import wikipedia
import json
import os
import uuid
import datetime
import tqdm

# %% [markdown]
# ## **Example: Basic pipeline with Spacy**
# In the following example, we explore building a basic natural language processing pipeline using the Spacy library, a powerful and efficient tool for this purpose. The goal is to understand how to assemble and use a pipeline that already has a set of integrated functionalities, providing a solid foundation for text processing and analysis.

# %%
# Loading the downloaded English model:
wikipedia.set_lang('en')
nlp = spacy.load('en_core_web_sm')

# Loading the text:
text = wikipedia.page('Natural Language Processing')
text
text.content
# Out:
# 'Natural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.\nMajor processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.\n\n\n== History ==\n\nNatural language processing has its roots in the 1950s. Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.\n\n\n=== Symbolic NLP (1950s – early 1990s) ===\n\nThe premise of symbolic NLP is often illustrated using John Searle\'s Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.\n\n1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem.  However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe) until the late 1980s when the first statistical machine translation systems were developed.\n1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapy, written by Joseph Weizenbaum between 1964 and 1966. Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?". Ross Quillian\'s successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer  memory at the time.\n1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data.  Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).  During this time, the first chatterbots were written (e.g., PARRY).\n1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP. Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory). Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky. An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period.\n\n\n=== Statistical NLP (1990s–present) ===\nUp until the 1980s, most natural langu ...

# %%
# Processing text with spaCy and exploring functions:
doc = nlp(text.content)
type(doc)

doc[0]
len(doc)

print(doc.to_json())
print(json.dumps(doc.to_json(), indent=4, ensure_ascii=False))

doc[0].pos_
doc[0].dep_
doc[0].head

(doc[0].text, doc[0].pos_ + "/" + doc[0].dep_, doc[0].head)
# Out:
# {'text': 'Natural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.\nMajor processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.\n\n\n== History ==\n\nNatural language processing has its roots in the 1950s. Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.\n\n\n=== Symbolic NLP (1950s – early 1990s) ===\n\nThe premise of symbolic NLP is often illustrated using John Searle\'s Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.\n\n1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem.  However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe) until the late 1980s when the first statistical machine translation systems were developed.\n1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapy, written by Joseph Weizenbaum between 1964 and 1966. Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?". Ross Quillian\'s successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer  memory at the time.\n1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data.  Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).  During this time, the first chatterbots were written (e.g., PARRY).\n1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP. Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory). Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky. An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period.\n\n\n=== Statistical NLP (1990s–present) ===\nUp until the 1980s, most natu ...
# {
#     "text": "Natural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.\nMajor processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.\n\n\n== History ==\n\nNatural language processing has its roots in the 1950s. Already in 1950, Alan Turing published an article titled \"Computing Machinery and Intelligence\" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.\n\n\n=== Symbolic NLP (1950s – early 1990s) ===\n\nThe premise of symbolic NLP is often illustrated using John Searle's Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.\n\n1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem.  However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe) until the late 1980s when the first statistical machine translation systems were developed.\n1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted \"blocks worlds\" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapy, written by Joseph Weizenbaum between 1964 and 1966. Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like. When the \"patient\" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to \"My head hurts\" with \"Why do you say your head hurts?\". Ross Quillian's successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer  memory at the time.\n1970s: During the 1970s, many programmers began to write \"conceptual ontologies\", which structured real-world information into computer-understandable data.  Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).  During this time, the first chatterbots were written (e.g., PARRY).\n1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP. Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory). Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky. An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period.\n\n\n=== Statistical NLP (1990s–present) ===\nUp until the 198 ...
#     "ents": [
#         {
#             "start": 29,
#             "end": 32,
#             "label": "ORG"
#         },
#         {
#             "start": 99,
#             "end": 102,
#             "label": "ORG"
#         },
#         {
#             "start": 193,
#             "end": 196,
#             "label": "ORG"
#         },
#         {
#             "start": 351,
#             "end": 354,
#             "label": "ORG"
#         },
#         {
#             "start": 539,
#             "end": 548,
#             "label": "DATE"
#         },
#         {
#             "start": 561,
#             "end": 565,
#             "label": "DATE"
#         },
#         {
#             "start": 567,
#             "end": 578,
#             "label": "PERSON"
#         },
#         {
#             "start": 607,
#             "end": 644,
#             "label": "WORK_OF_ART"
#         },
#         {
#             "start": 684,
#             "end": 690,
#             "label": "ORG"
#         },
#         {
#             "start": 943,
#             "end": 955,
#             "label": "PERSON"
#         },
#         {
#             "start": 957,
#             "end": 962,
#             "label": "DATE"
#         },
#         {
#             "start": 965,
#             "end": 976,
#             "label": "DATE"
#         },
#         {
#             "start": 1007,
#             "end": 1010,
#             "label": "ORG"
#         },
#         {
#             "start": 1038,
#             "end": 1051,
#             "label": "PERSON"
#         },
#         {
#             "start": 1052,
#             "end": 1059,
#             "label": "NORP"
#         },
#         {
#             "start": 1122,
#             "end": 1129,
#             "label": "NORP"
#         },
#         {
#             "start": 1243,
#             "end": 1246,
#             "label": "ORG"
#         },
#         {
#             "start": 1305,
#             "end": 1310,
#             "label": "DATE"
#         },
#         {
#             "start": 1316,
#             "end": 1326,
#             "label": "ORG"
#         },
#         {
#             "start": 1341,
#             "end": 1345,
#             "label": "DATE"
#         },
#         {
#             "start": 1386,
#             "end": 1401,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 1402,
#             "end": 1409,
#             "label": "NORP"
#         },
#         {
#             "start": 1425,
#             "end": 1432,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 1466,
#             "end": 1485,
#             "label": "DATE"
#         },
#         {
#             "start": 1589,
#             "end": 1594,
#             "label": "ORG"
#         },
#         {
#             "start": 1605,
#             "end": 1609,
#             "label": "DATE"
#         },
#         {
#             "start": 1628,
#             "end": 1637,
#             "label": "DATE"
#         },
#         {
#             "start": 1812,
#             "end": 1819,
#             "label": "GPE"
#         },
#         {
#             "start": 1871,
#             "end": 1876,
#             "label": "GPE"
#         },
#         {
#             "start": 1881,
#             "end": 1887,
#             "label": "LOC"
#         },
#         {
#             "start": 1895,
#             "end": 1909,
#             "label": "DATE"
#         },
#         {
#             "start": 1919,
#             "end": 1924,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 2061,
#             "end": 2070,
#             "label": "DATE"
#         },
#         {
#             "start": 2076,
#             "end": 2082,
#             "label": "ORG"
#         },
#         {
#             "start": 2182,
#             "end": 2187,
#             "label": "ORG"
#         },
#         {
#             "start": 2207,
#             "end": 2215,
#             "label": "NORP"
#         },
#         {
#             "start": 2242,
#             "end": 2259,
#             "label": "PERSON"
#         },
#         {
#             "start": 2260,
#             "end": 2281,
#             "label": "DATE"
#         },
#         {
#             "start": 2349,
#             "end": 2354,
#             "label": "ORG"
#         },
#         {
#             "start": 2473,
#             "end": 2478,
#             "label": "ORG"
#         },
#         {
#             "start": 2596,
#             "end": 2611,
#             "label": "PERSON"
#         },
#         {
#             "start": 2686,
#             "end": 2697,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 2790,
#             "end": 2799,
#             "label": "DATE"
#         },
#         {
#             "start": 2963,
#             "end": 2967,
#             "label": "DATE"
#         },
#         {
#             "start": 2970,
#             "end": 2973,
#             "label": "PERSON"
#         },
#         {
#             "start": 2975,
#             "end": 2986,
#             "label": "GPE"
#         },
#         {
#             "start": 2988,
#             "end": 2992,
#             "label": "DATE"
#         },
#         {
#             "start": 2995,
#             "end": 2998,
#             "label": "ORG"
#         },
#         {
#             "start": 3000,
#             "end": 3008,
#             "label": "PERSON"
#         },
#         {
#             "start": 3010,
#             "end": 3014,
#             "label": "DATE"
#         },
#         {
#             "start": 3017,
#             "end": 3025,
#             "label": "PRODUCT"
#         },
#         {
#             "start": 3035,
#             "end": 3039,
#             "label": "DATE"
#         },
#         {
#             "start": 3042,
#             "end": 3047,
#             "label": "PERSON"
#         },
#         {
#             "start": 3049,
#             "end": 3056,
#             "label": "PERSON"
#         },
#         {
#             "start": 3058,
#             "end": 3062,
#             "label": "DATE"
#         },
#         {
#             "start": 3075,
#             "end": 3084,
#             "label": "PERSON"
#         },
#         {
#             "start": 3086,
#             "end": 3090,
#             "label": "DATE"
#         },
#         {
#             "start": 3097,
#             "end": 3107,
#             "label": "ORG"
#         },
#         {
#             "start": 3109,
#             "end": 3116,
#             "label": "PERSON"
#         },
#         {
#             "start": 3117,
#             "end": 3121,
#             "label": "DATE"
#         },
#         {
#             "start": 3147,
#             "end": 3152,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 3193,
#             "end": 3198,
#             "label": "DATE"
#         },
#         {
#             "start": 3200,
#             "end": 3209,
#             "label": "DATE"
#         },
#         {
#             "start": 3214,
#             "end": 3225,
#             "label": "DATE"
#         },
#         {
#             "start": 3265,
#             "end": 3268,
#             "label": "ORG"
#         },
#         {
#             "start": 3360,
#             "end": 3364,
#             "label": "ORG"
#         },
#         {
#             "start": 3445,
#             "end": 3448,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 3485,
#             "end": 3499,
#             "label": "PERSON"
#         },
#         {
#             "start": 3526,
#             "end": 3542,
#             "label": "PERSON"
#         },
#         {
#             "start": 3604,
#             "end": 3635,
#             "label": "ORG"
#         },
#         {
#             "start": 3720,
#             "end": 3726,
#             "label": "PERSON"
#         },
#         {
#             "start": 3731,
#             "end": 3742,
#             "label": "PERSON"
#         },
#         {
#             "start": 3817,
#             "end": 3826,
#             "label": "DATE"
#         },
#         {
#             "start": 3915,
#             "end": 3918,
#             "label": "ORG"
#         },
#         {
#             "start": 3920,
#             "end": 3925,
#             "label": "DATE"
#         },
#         {
#             "start": 3948,
#             "end": 3957,
#             "label": "DATE"
#         },
#         {
#             "start": 4062,
#             "end": 4076,
#             "label": "DATE"
#         },
#         {
#             "start": 4284,
#             "end": 4289,
#             "label": "PERSON"
#         },
#         {
#             "start": 4331,
#             "end": 4340,
#             "label": "NORP"
#         },
#         {
#             "start": 4612,
#             "end": 4615,
#             "label": "ORG"
#         },
#         {
#             "start": 4688,
#             "end": 4700,
#             "label": "ORG"
#         },
#         {
#             "start": 4710,
#             "end": 4713,
#             "label": "ORG"
#         },
#         {
#             "start": 4841,
#             "end": 4865,
#             "label": "ORG"
#         },
#         {
#             "start": 4870,
#             "end": 4888,
#             "label": "ORG"
#         },
#         {
#             "start": 5503,
#             "end": 5516,
#             "label": "DATE"
#         },
#         {
#             "start": 6033,
#             "end": 6051,
#             "label": "EVENT"
#         },
#         {
#             "start": 6175,
#             "end": 6179,
#             "label": "DATE"
#         },
#         {
#             "start": 6370,
#             "end": 6380,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 6391,
#             "end": 6397,
#             "label": "PERSON"
#         },
#         {
#             "start": 6406,
#             "end": 6410,
#             "label": "DATE"
#         },
#         {
#             "start": 6412,
#             "end": 6425,
#             "label": "ORG"
#         },
#         {
#             "start": 6434,
#             "end": 6437,
#             "label": "WORK_OF_ART"
#         },
#         {
#             "start": 6449,
#             "end": 6478,
#             "label": "ORG"
#         },
#         {
#             "start": 6594,
#             "end": 6613,
#             "label": "DATE"
#         },
#         {
#             "start": 6649,
#             "end": 6658,
#             "label": "DATE"
#         },
#         {
#             "start": 7065,
#             "end": 7068,
#             "label": "ORG"
#         },
#         {
#             "start": 7248,
#             "end": 7256,
#             "label": "PERSON"
#         },
#         {
#             "start": 7290,
#             "end": 7298,
#             "label": "PERSON"
#         },
#         {
#             "start": 7430,
#             "end": 7435,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 7458,
#             "end": 7460,
#             "label": "GPE"
#         },
#         {
#             "start": 7479,
#             "end": 7482,
#             "label": "ORG"
#         },
#         {
#             "start": 8731,
#             "end": 8739,
#             "label": "ORG"
#         },
#         {
#             "start": 8769,
#             "end": 8772,
#             "label": "ORG"
#         },
#         {
#             "start": 8858,
#             "end": 8861,
#             "label": "ORG"
#         },
#         {
#             "start": 8961,
#             "end": 8989,
#             "label": "DATE"
#         },
#         {
#             "start": 9034,
#             "end": 9036,
#             "label": "GPE"
#         },
#         {
#             "start": 9037,
#             "end": 9043,
#             "label": "DATE"
#         },
#         {
#             "start": 9274,
#             "end": 9280,
#             "label": "PERSON"
#         },
#         {
#             "start": 9499,
#             "end": 9503,
#             "label": "DATE"
#         },
#         {
#             "start": 10009,
#             "end": 10012,
#             "label": "ORG"
#         },
#         {
#             "start": 10497,
#             "end": 10500,
#             "label": "ORG"
#         },
#         {
#             "start": 11924,
#             "end": 11927,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 12233,
#             "end": 12240,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 12348,
#             "end": 12355,
#             "label": "NORP"
#         },
#         {
#             "start": 12357,
#             "end": 12365,
#             "label": "NORP"
#         },
#         {
#             "start": 12370,
#             "end": 12374,
#             "label": "NORP"
#         },
#         {
#             "start": 13267,
#             "end": 13274,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 13525,
#             "end": 13532,
#             "label": "NORP"
#         },
#         {
#             "start": 13566,
#             "end": 13572,
#             "label": "NORP"
#         },
#         {
#             "start": 13655,
#             "end": 13664,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 14009,
#             "end": 14022,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 14368,
#             "end": 14376,
#             "label": "PERSON"
#         },
#         {
#             "start": 14947,
#             "end": 14956,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 15048,
#             "end": 15051,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 15548,
#             "end": 15562,
#             "label": "ORG"
#         },
#         {
#             "start": 15652,
#             "end": 15655,
#             "label": "ORG"
#         },
#         {
#             "start": 15923,
#             "end": 15930,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 16073,
#             "end": 16078,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 16266,
#             "end": 16273,
#             "label": "NORP"
#         },
#         {
#             "start": 16277,
#             "end": 16283,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 16426,
#             "end": 16432,
#             "label": "NORP"
#         },
#         {
#             "start": 16498,
#             "end": 16504,
#             "label": "NORP"
#         },
#         {
#             "start": 16509,
#             "end": 16516,
#             "label": "NORP"
#         },
#         {
#             "start": 16978,
#             "end": 17019,
#             "label": "ORG"
#         },
#         {
#             "start": 17487,
#             "end": 17500,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 17718,
#             "end": 17725,
#             "label": "ORG"
#         },
#         {
#             "start": 17925,
#             "end": 17935,
#             "label": "ORG"
#         },
#         {
#             "start": 18253,
#             "end": 18256,
#             "label": "ORG"
#         },
#         {
#             "start": 18318,
#             "end": 18321,
#             "label": "ORG"
#         },
#         {
#             "start": 18401,
#             "end": 18404,
#             "label": "ORG"
#         },
#         {
#             "start": 18923,
#             "end": 18934,
#             "label": "PERSON"
#         },
#         {
#             "start": 19063,
#             "end": 19071,
#             "label": "PERSON"
#         },
#         {
#             "start": 19409,
#             "end": 19413,
#             "label": "PERSON"
#         },
#         {
#             "start": 19602,
#             "end": 19606,
#             "label": "PERSON"
#         },
#         {
#             "start": 19749,
#             "end": 19752,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 20606,
#             "end": 20610,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 20738,
#             "end": 20741,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 21441,
#             "end": 21444,
#             "label": "ORG"
#         },
#         {
#             "start": 21968,
#             "end": 21988,
#             "label": "MONEY"
#         },
#         {
#             "start": 22019,
#             "end": 22026,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 22032,
#             "end": 22038,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 22108,
#             "end": 22112,
#             "label": "DATE"
#         },
#         {
#             "start": 22295,
#             "end": 22299,
#             "label": "DATE"
#         },
#         {
#             "start": 22416,
#             "end": 22425,
#             "label": "ORG"
#         },
#         {
#             "start": 22497,
#             "end": 22499,
#             "label": "ORG"
#         },
#         {
#             "start": 22535,
#             "end": 22538,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 22866,
#             "end": 22869,
#             "label": "ORG"
#         },
#         {
#             "start": 22871,
#             "end": 22878,
#             "label": "PERSON"
#         },
#         {
#             "start": 22935,
#             "end": 22940,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 23514,
#             "end": 23517,
#             "label": "ORG"
#         },
#         {
#             "start": 23581,
#             "end": 23591,
#             "label": "ORG"
#         },
#         {
#             "start": 23699,
#             "end": 23706,
#             "label": "ORG"
#         },
#         {
#             "start": 23816,
#             "end": 23819,
#             "label": "ORG"
#         },
#         {
#             "start": 23890,
#             "end": 23893,
#             "label": "ORG"
#         },
#         {
#             "start": 23943,
#             "end": 23948,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 24010,
#             "end": 24014,
#             "label": "DATE"
#         },
#         {
#             "start": 24049,
#             "end": 24053,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 24072,
#             "end": 24077,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 24130,
#             "end": 24134,
#             "label": "DATE"
#         },
#         {
#             "start": 24136,
#             "end": 24137,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 24178,
#             "end": 24191,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 24297,
#             "end": 24302,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 24351,
#             "end": 24355,
#             "label": "DATE"
#         },
#         {
#             "start": 24403,
#             "end": 24407,
#             "label": "PERSON"
#         },
#         {
#             "start": 24428,
#             "end": 24429,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 24565,
#             "end": 24568,
#             "label": "ORG"
#         },
#         {
#             "start": 24668,
#             "end": 24671,
#             "label": "ORG"
#         },
#         {
#             "start": 24770,
#             "end": 24773,
#             "label": "ORG"
#         },
#         {
#             "start": 25156,
#             "end": 25162,
#             "label": "GPE"
#         },
#         {
#             "start": 25709,
#             "end": 25712,
#             "label": "ORG"
#         },
#         {
#             "start": 25720,
#             "end": 25724,
#             "label": "DATE"
#         },
#         {
#             "start": 25726,
#             "end": 25731,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 25787,
#             "end": 25805,
#             "label": "ORG"
#         },
#         {
#             "start": 25963,
#             "end": 25978,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 25999,
#             "end": 26014,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 26040,
#             "end": 26047,
#             "label": "ORDINAL"
#         },
#         {
#             "start": 26089,
#             "end": 26093,
#             "label": "DATE"
#         },
#         {
#             "start": 26187,
#             "end": 26194,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 26201,
#             "end": 26205,
#             "label": "DATE"
#         },
#         {
#             "start": 26207,
#             "end": 26214,
#             "label": "NORP"
#         },
#         {
#             "start": 26216,
#             "end": 26221,
#             "label": "NORP"
#         },
#         {
#             "start": 26228,
#             "end": 26232,
#             "label": "DATE"
#         },
#         {
#             "start": 26234,
#             "end": 26240,
#             "label": "NORP"
#         },
#         {
#             "start": 26247,
#             "end": 26251,
#             "label": "DATE"
#         },
#         {
#             "start": 26253,
#             "end": 26262,
#             "label": "NORP"
#         },
#         {
#             "start": 26264,
#             "end": 26270,
#             "label": "NORP"
#         },
#         {
#             "start": 26272,
#             "end": 26280,
#             "label": "NORP"
#         },
#         {
#             "start": 26282,
#             "end": 26292,
#             "label": "NORP"
#         },
#         {
#             "start": 26294,
#             "end": 26303,
#             "label": "NORP"
#         },
#         {
#             "start": 26305,
#             "end": 26312,
#             "label": "NORP"
#         },
#         {
#             "start": 26314,
#             "end": 26321,
#             "label": "NORP"
#         },
#         {
#             "start": 26328,
#             "end": 26332,
#             "label": "DATE"
#         },
#         {
#             "start": 26334,
#             "end": 26340,
#             "label": "NORP"
#         },
#         {
#             "start": 26342,
#             "end": 26349,
#             "label": "NORP"
#         },
#         {
#             "start": 26351,
#             "end": 26358,
#             "label": "NORP"
#         },
#         {
#             "start": 26360,
#             "end": 26365,
#             "label": "NORP"
#         },
#         {
#             "start": 26367,
#             "end": 26376,
#             "label": "NORP"
#         },
#         {
#             "start": 26378,
#             "end": 26385,
#             "label": "NORP"
#         },
#         {
#             "start": 26387,
#             "end": 26394,
#             "label": "NORP"
#         },
#         {
#             "start": 26401,
#             "end": 26405,
#             "label": "DATE"
#         },
#         {
#             "start": 26407,
#             "end": 26412,
#             "label": "NORP"
#         },
#         {
#             "start": 26419,
#             "end": 26423,
#             "label": "DATE"
#         },
#         {
#             "start": 26425,
#             "end": 26431,
#             "label": "NORP"
#         },
#         {
#             "start": 26438,
#             "end": 26442,
#             "label": "DATE"
#         },
#         {
#             "start": 26444,
#             "end": 26448,
#             "label": "DATE"
#         },
#         {
#             "start": 26450,
#             "end": 26463,
#             "label": "DATE"
#         },
#         {
#             "start": 26465,
#             "end": 26469,
#             "label": "DATE"
#         },
#         {
#             "start": 26471,
#             "end": 26489,
#             "label": "DATE"
#         },
#         {
#             "start": 26680,
#             "end": 26683,
#             "label": "ORG"
#         },
#         {
#             "start": 26917,
#             "end": 26920,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 26958,
#             "end": 26961,
#             "label": "ORG"
#         },
#         {
#             "start": 27414,
#             "end": 27417,
#             "label": "ORG"
#         },
#         {
#             "start": 27519,
#             "end": 27532,
#             "label": "PERSON"
#         },
#         {
#             "start": 27592,
#             "end": 27595,
#             "label": "ORG"
#         },
#         {
#             "start": 27709,
#             "end": 27712,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 27786,
#             "end": 27792,
#             "label": "PERSON"
#         },
#         {
#             "start": 27818,
#             "end": 27821,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 27927,
#             "end": 27934,
#             "label": "LANGUAGE"
#         },
#         {
#             "start": 28140,
#             "end": 28148,
#             "label": "DATE"
#         },
#         {
#             "start": 28152,
#             "end": 28161,
#             "label": "DATE"
#         },
#         {
#             "start": 28329,
#             "end": 28332,
#             "label": "ORG"
#         },
#         {
#             "start": 28673,
#             "end": 28675,
#             "label": "GPE"
#         },
#         {
#             "start": 28683,
#             "end": 28690,
#             "label": "DATE"
#         },
#         {
#             "start": 29168,
#             "end": 29169,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 29197,
#             "end": 29198,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 29376,
#             "end": 29394,
#             "label": "PERSON"
#         },
#         {
#             "start": 29531,
#             "end": 29579,
#             "label": "PRODUCT"
#         },
#         {
#             "start": 29833,
#             "end": 29849,
#             "label": "PRODUCT"
#         },
#         {
#             "start": 30003,
#             "end": 30004,
#             "label": "GPE"
#         },
#         {
#             "start": 30387,
#             "end": 30388,
#             "label": "ORG"
#         },
#         {
#             "start": 30703,
#             "end": 30720,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 30820,
#             "end": 30823,
#             "label": "ORG"
#         },
#         {
#             "start": 30953,
#             "end": 30956,
#             "label": "ORG"
#         },
#         {
#             "start": 31024,
#             "end": 31028,
#             "label": "CARDINAL"
#         },
#         {
#             "start": 31207,
#             "end": 31210,
#             "label": "ORG"
#         },
#         {
#             "start": 31291,
#             "end": 31300,
#             "label": "DATE"
#         },
#         {
#             "start": 31647,
#             "end": 31650,
#             "label": "ORG"
#         },
#         {
#             "start": 31704,
#             "end": 31707,
#             "label": "ORG"
#         },
#         {
#             "start": 31744,
#             "end": 31747,
#             "label": "ORG"
#         },
#         {
#             "start": 31879,
#             "end": 31882,
#             "label": "ORG"
#         },
#         {
#             "start": 31924,
#             "end": 31927,
#             "label": "ORG"
#         },
#         {
#             "start": 32171,
#             "end": 32178,
#             "label": "NORP"
#         },
#         {
#             "start": 32214,
#             "end": 32232,
#             "label": "ORG"
#         },
#         {
#             "start": 32240,
#             "end": 32255,
#             "label": "PERSON"
#         },
#         {
#             "start": 32389,
#             "end": 32406,
#             "label": "ORG"
#         }
#     ],
#     "sents": [
#         {
#             "start": 0,
#             "end": 98
#         },
#         {
#             "start": 99,
#             "end": 192
#         },
#         {
#             "start": 193,
#             "end": 322
#         },
#         {
#             "start": 322,
#             "end": 479
#         },
#         {
#             "start": 479,
#             "end": 549
#         },
#         {
#             "start": 550,
#             "end": 823
#         },
#         {
#             "start": 824,
#             "end": 939
#         },
#         {
#             "start": 939,
#             "end": 977
#         },
#         {
#             "start": 978,
#             "end": 1311
#         },
#         {
#             "start": 1312,
#             "end": 1433
#         },
#         {
#             "start": 1434,
#             "end": 1535
#         },
#         {
#             "start": 1535,
#             "end": 1747
#         },
#         {
#             "start": 1748,
#             "end": 2282
#         },
#         {
#             "start": 2283,
#             "end": 2413
#         },
#         {
#             "start": 2414,
#             "end": 2595
#         },
#         {
#             "start": 2596,
#             "end": 2782
#         },
#         {
#             "start": 2783,
#             "end": 2934
#         },
#         {
#             "start": 2934,
#             "end": 3125
#         },
#         {
#             "start": 3125,
#             "end": 3269
#         },
#         {
#             "start": 3270,
#             "end": 3637
#         },
#         {
#             "start": 3638,
#             "end": 3743
#         },
#         {
#             "start": 3744,
#             "end": 3899
#         },
#         {
#             "start": 3899,
#             "end": 4049
#         },
#         {
#             "start": 4050,
#             "end": 4218
#         },
#         {
#             "start": 4219,
#             "end": 4363
#         },
#         {
#             "start": 4364,
#             "end": 4549
#         },
#         {
#             "start": 4550,
#             "end": 4731
#         },
#         {
#             "start": 4732,
#             "end": 5040
#         },
#         {
#             "start": 5041,
#             "end": 5158
#         },
#         {
#             "start": 5159,
#             "end": 5272
#         },
#         {
#             "start": 5273,
#             "end": 5517
#         },
#         {
#             "start": 5518,
#             "end": 5613
#         },
#         {
#             "start": 5614,
#             "end": 5767
#         },
#         {
#             "start": 5768,
#             "end": 5916
#         },
#         {
#             "start": 5917,
#             "end": 6411
#         },
#         {
#             "start": 6412,
#             "end": 6645
#         },
#         {
#             "start": 6646,
#             "end": 6819
#         },
#         {
#             "start": 6820,
#             "end": 6999
#         },
#         {
#             "start": 7000,
#             "end": 7233
#         },
#         {
#             "start": 7233,
#             "end": 7568
#         },
#         {
#             "start": 7568,
#             "end": 8277
#         },
#         {
#             "start": 8277,
#             "end": 8511
#         },
#         {
#             "start": 8511,
#             "end": 8929
#         },
#         {
#             "start": 8929,
#             "end": 9114
#         },
#         {
#             "start": 9114,
#             "end": 9242
#         },
#         {
#             "start": 9242,
#             "end": 9376
#         },
#         {
#             "start": 9376,
#             "end": 9492
#         },
#         {
#             "start": 9493,
#             "end": 9684
#         },
#         {
#             "start": 9684,
#             "end": 9782
#         },
#         {
#             "start": 9782,
#             "end": 9999
#         },
#         {
#             "start": 9999,
#             "end": 10123
#         },
#         {
#             "start": 10124,
#             "end": 10272
#         },
#         {
#             "start": 10272,
#             "end": 10393
#         },
#         {
#             "start": 10394,
#             "end": 10430
#         },
#         {
#             "start": 10430,
#             "end": 10578
#         },
#         {
#             "start": 10578,
#             "end": 10701
#         },
#         {
#             "start": 10701,
#             "end": 10835
#         },
#         {
#             "start": 10835,
#             "end": 10993
#         },
#         {
#             "start": 10994,
#             "end": 11215
#         },
#         {
#             "start": 11216,
#             "end": 11458
#         },
#         {
#             "start": 11458,
#             "end": 11554
#         },
#         {
#             "start": 11554,
#             "end": 11617
#         },
#         {
#             "start": 11617,
#             "end": 11704
#         },
#         {
#             "start": 11705,
#             "end": 11762
#         },
#         {
#             "start": 11762,
#             "end": 11897
#         },
#         {
#             "start": 11898,
#             "end": 11976
#         },
#         {
#             "start": 11977,
#             "end": 12141
#         },
#         {
#             "start": 12142,
#             "end": 12213
#         },
#         {
#             "start": 12213,
#             "end": 12310
#         },
#         {
#             "start": 12311,
#             "end": 12563
#         },
#         {
#             "start": 12564,
#             "end": 12660
#         },
#         {
#             "start": 12660,
#             "end": 12833
#         },
#         {
#             "start": 12834,
#             "end": 12913
#         },
#         {
#             "start": 12914,
#             "end": 13013
#         },
#         {
#             "start": 13013,
#             "end": 13121
#         },
#         {
#             "start": 13122,
#             "end": 13266
#         },
#         {
#             "start": 13267,
#             "end": 13503
#         },
#         {
#             "start": 13504,
#             "end": 13689
#         },
#         {
#             "start": 13689,
#             "end": 13779
#         },
#         {
#             "start": 13780,
#             "end": 13854
#         },
#         {
#             "start": 13855,
#             "end": 14050
#         },
#         {
#             "start": 14050,
#             "end": 14218
#         },
#         {
#             "start": 14219,
#             "end": 14322
#         },
#         {
#             "start": 14322,
#             "end": 14430
#         },
#         {
#             "start": 14430,
#             "end": 14551
#         },
#         {
#             "start": 14552,
#             "end": 14710
#         },
#         {
#             "start": 14710,
#             "end": 14786
#         },
#         {
#             "start": 14787,
#             "end": 15037
#         },
#         {
#             "start": 15038,
#             "end": 15122
#         },
#         {
#             "start": 15123,
#             "end": 15404
#         },
#         {
#             "start": 15404,
#             "end": 15458
#         },
#         {
#             "start": 15459,
#             "end": 15548
#         },
#         {
#             "start": 15548,
#             "end": 15626
#         },
#         {
#             "start": 15626,
#             "end": 15657
#         },
#         {
#             "start": 15657,
#             "end": 15839
#         },
#         {
#             "start": 15840,
#             "end": 16056
#         },
#         {
#             "start": 16056,
#             "end": 16203
#         },
#         {
#             "start": 16203,
#             "end": 16412
#         },
#         {
#             "start": 16413,
#             "end": 16566
#         },
#         {
#             "start": 16567,
#             "end": 16622
#         },
#         {
#             "start": 16622,
#             "end": 16682
#         },
#         {
#             "start": 16682,
#             "end": 16775
#         },
#         {
#             "start": 16776,
#             "end": 16894
#         },
#         {
#             "start": 16895,
#             "end": 17178
#         },
#         {
#             "start": 17179,
#             "end": 17317
#         },
#         {
#             "start": 17317,
#             "end": 17439
#         },
#         {
#             "start": 17439,
#             "end": 17471
#         },
#         {
#             "start": 17471,
#             "end": 17580
#         },
#         {
#             "start": 17580,
#             "end": 17727
#         },
#         {
#             "start": 17727,
#             "end": 17921
#         },
#         {
#             "start": 17921,
#             "end": 17981
#         },
#         {
#             "start": 17982,
#             "end": 18112
#         },
#         {
#             "start": 18112,
#             "end": 18331
#         },
#         {
#             "start": 18332,
#             "end": 18631
#         },
#         {
#             "start": 18631,
#             "end": 18705
#         },
#         {
#             "start": 18705,
#             "end": 18865
#         },
#         {
#             "start": 18865,
#             "end": 19062
#         },
#         {
#             "start": 19063,
#             "end": 19219
#         },
#         {
#             "start": 19220,
#             "end": 19361
#         },
#         {
#             "start": 19362,
#             "end": 19685
#         },
#         {
#             "start": 19685,
#             "end": 19749
#         },
#         {
#             "start": 19749,
#             "end": 19952
#         },
#         {
#             "start": 19952,
#             "end": 20110
#         },
#         {
#             "start": 20110,
#             "end": 20330
#         },
#         {
#             "start": 20331,
#             "end": 20579
#         },
#         {
#             "start": 20580,
#             "end": 20701
#         },
#         {
#             "start": 20701,
#             "end": 20883
#         },
#         {
#             "start": 20883,
#             "end": 21043
#         },
#         {
#             "start": 21043,
#             "end": 21223
#         },
#         {
#             "start": 21224,
#             "end": 21424
#         },
#         {
#             "start": 21424,
#             "end": 21556
#         },
#         {
#             "start": 21556,
#             "end": 21692
#         },
#         {
#             "start": 21692,
#             "end": 21908
#         },
#         {
#             "start": 21909,
#             "end": 22048
#         },
#         {
#             "start": 22049,
#             "end": 22113
#         },
#         {
#             "start": 22114,
#             "end": 22398
#         },
#         {
#             "start": 22398,
#             "end": 22476
#         },
#         {
#             "start": 22476,
#             "end": 22567
#         },
#         {
#             "start": 22567,
#             "end": 22834
#         },
#         {
#             "start": 22834,
#             "end": 23016
#         },
#         {
#             "start": 23017,
#             "end": 23275
#         },
#         {
#             "start": 23276,
#             "end": 23379
#         },
#         {
#             "start": 23380,
#             "end": 23664
#         },
#         {
#             "start": 23664,
#             "end": 23793
#         },
#         {
#             "start": 23793,
#             "end": 23938
#         },
#         {
#             "start": 23939,
#             "end": 24067
#         },
#         {
#             "start": 24068,
#             "end": 24198
#         },
#         {
#             "start": 24199,
#             "end": 24292
#         },
#         {
#             "start": 24293,
#             "end": 24409
#         },
#         {
#             "start": 24410,
#             "end": 24511
#         },
#         {
#             "start": 24511,
#             "end": 24769
#         },
#         {
#             "start": 24770,
#             "end": 24930
#         },
#         {
#             "start": 24930,
#             "end": 25002
#         },
#         {
#             "start": 25002,
#             "end": 25075
#         },
#         {
#             "start": 25076,
#             "end": 25264
#         },
#         {
#             "start": 25264,
#             "end": 25370
#         },
#         {
#             "start": 25370,
#             "end": 25461
#         },
#         {
#             "start": 25461,
#             "end": 25556
#         },
#         {
#             "start": 25556,
#             "end": 25713
#         },
#         {
#             "start": 25714,
#             "end": 26114
#         },
#         {
#             "start": 26114,
#             "end": 26644
#         },
#         {
#             "start": 26644,
#             "end": 26794
#         },
#         {
#             "start": 26795,
#             "end": 27007
#         },
#         {
#             "start": 27007,
#             "end": 27143
#         },
#         {
#             "start": 27144,
#             "end": 27235
#         },
#         {
#             "start": 27236,
#             "end": 27375
#         },
#         {
#             "start": 27376,
#             "end": 27504
#         },
#         {
#             "start": 27504,
#             "end": 27900
#         },
#         {
#             "start": 27901,
#             "end": 27944
#         },
#         {
#             "start": 27945,
#             "end": 28113
#         },
#         {
#             "start": 28113,
#             "end": 28207
#         },
#         {
#             "start": 28207,
#             "end": 28381
#         },
#         {
#             "start": 28381,
#             "end": 28610
#         },
#         {
#             "start": 28611,
#             "end": 28920
#         },
#         {
#             "start": 28920,
#             "end": 30545
#         },
#         {
#             "start": 30545,
#             "end": 31301
#         },
#         {
#             "start": 31302,
#             "end": 31709
#         },
#         {
#             "start": 31710,
#             "end": 31849
#         },
#         {
#             "start": 31850,
#             "end": 32259
#         },
#         {
#             "start": 32259,
#             "end": 32406
#         }
#     ],
#     "tokens": [
#         {
#             "id": 0,
#             "start": 0,
#             "end": 7,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "natural",
#             "dep": "amod",
#             "head": 1
#         },
#         {
#             "id": 1,
#             "start": 8,
#             "end": 16,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "language",
#             "dep": "compound",
#             "head": 2
#         },
#         {
# ...
#             "head": 5817
#         },
#         {
#             "id": 5822,
#             "start": 32101,
#             "end": 32111,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "artificial",
#             "dep": "amod",
#             "head": 5824
#         },
#         {
#             "id": 5823,
#             "start": 32112,
#             "end": 32119,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "general",
#             "dep": "amod",
#             "head": 5824
#         },
#         {
#             "id": 5824,
#             "start": 32120,
#             "end": 32132,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "intelligence",
#             "dep": "pobj",
#             "head": 5821
#         },
#         {
#             "id": 5825,
#             "start": 32133,
#             "end": 32138,
#             "tag": "VBN",
#             "pos": "VERB",
#             "morph": "Aspect=Perf|Tense=Past|VerbForm=Part",
#             "lemma": "base",
#             "dep": "acl",
#             "head": 5810
#         },
#         {
#             "id": 5826,
#             "start": 32139,
#             "end": 32141,
#             "tag": "IN",
#             "pos": "ADP",
#             "morph": "",
#             "lemma": "on",
#             "dep": "prep",
#             "head": 5825
#         },
#         {
#             "id": 5827,
#             "start": 32142,
#             "end": 32145,
#             "tag": "DT",
#             "pos": "DET",
#             "morph": "Definite=Def|PronType=Art",
#             "lemma": "the",
#             "dep": "det",
#             "head": 5830
#         },
#         {
#             "id": 5828,
#             "start": 32146,
#             "end": 32150,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "free",
#             "dep": "amod",
#             "head": 5829
#         },
#         {
#             "id": 5829,
#             "start": 32151,
#             "end": 32157,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "energy",
#             "dep": "compound",
#             "head": 5830
#         },
#         {
#             "id": 5830,
#             "start": 32158,
#             "end": 32167,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "principle",
#             "dep": "pobj",
#             "head": 5826
#         },
#         {
#             "id": 5831,
#             "start": 32168,
#             "end": 32170,
#             "tag": "IN",
#             "pos": "ADP",
#             "morph": "",
#             "lemma": "by",
#             "dep": "prep",
#             "head": 5830
#         },
#         {
#             "id": 5832,
#             "start": 32171,
#             "end": 32178,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "british",
#             "dep": "amod",
#             "head": 5833
#         },
#         {
#             "id": 5833,
#             "start": 32179,
#             "end": 32193,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "neuroscientist",
#             "dep": "pobj",
#             "head": 5831
#         },
#         {
#             "id": 5834,
#             "start": 32194,
#             "end": 32197,
#             "tag": "CC",
#             "pos": "CCONJ",
#             "morph": "ConjType=Cmp",
#             "lemma": "and",
#             "dep": "cc",
#             "head": 5833
#         },
#         {
#             "id": 5835,
#             "start": 32198,
#             "end": 32210,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "theoretician",
#             "dep": "conj",
#             "head": 5833
#         },
#         {
#             "id": 5836,
#             "start": 32211,
#             "end": 32213,
#             "tag": "IN",
#             "pos": "ADP",
#             "morph": "",
#             "lemma": "at",
#             "dep": "prep",
#             "head": 5833
#         },
#         {
#             "id": 5837,
#             "start": 32214,
#             "end": 32224,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "University",
#             "dep": "compound",
#             "head": 5838
#         },
#         {
#             "id": 5838,
#             "start": 32225,
#             "end": 32232,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "College",
#             "dep": "compound",
#             "head": 5839
#         },
#         {
#             "id": 5839,
#             "start": 32233,
#             "end": 32239,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "London",
#             "dep": "compound",
#             "head": 5842
#         },
#         {
#             "id": 5840,
#             "start": 32240,
#             "end": 32244,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "Karl",
#             "dep": "compound",
#             "head": 5842
#         },
#         {
#             "id": 5841,
#             "start": 32245,
#             "end": 32247,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "J.",
#             "dep": "compound",
#             "head": 5842
#         },
#         {
#             "id": 5842,
#             "start": 32248,
#             "end": 32255,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "Friston",
#             "dep": "pobj",
#             "head": 5836
#         },
#         {
#             "id": 5843,
#             "start": 32255,
#             "end": 32256,
#             "tag": ".",
#             "pos": "PUNCT",
#             "morph": "PunctType=Peri",
#             "lemma": ".",
#             "dep": "punct",
#             "head": 5790
#         },
#         {
#             "id": 5844,
#             "start": 32256,
#             "end": 32259,
#             "tag": "_SP",
#             "pos": "SPACE",
#             "morph": "",
#             "lemma": "\n\n\n",
#             "dep": "dep",
#             "head": 5843
#         },
#         {
#             "id": 5845,
#             "start": 32259,
#             "end": 32260,
#             "tag": "PRP",
#             "pos": "PRON",
#             "morph": "PronType=Prs",
#             "lemma": "=",
#             "dep": "nsubj",
#             "head": 5847
#         },
#         {
#             "id": 5846,
#             "start": 32260,
#             "end": 32261,
#             "tag": "VBP",
#             "pos": "VERB",
#             "morph": "Tense=Pres|VerbForm=Fin",
#             "lemma": "=",
#             "dep": "nsubj",
#             "head": 5847
#         },
#         {
#             "id": 5847,
#             "start": 32262,
#             "end": 32265,
#             "tag": "VB",
#             "pos": "VERB",
#             "morph": "VerbForm=Inf",
#             "lemma": "see",
#             "dep": "ROOT",
#             "head": 5847
#         },
#         {
#             "id": 5848,
#             "start": 32266,
#             "end": 32270,
#             "tag": "RB",
#             "pos": "ADV",
#             "morph": "",
#             "lemma": "also",
#             "dep": "advmod",
#             "head": 5847
#         },
#         {
#             "id": 5849,
#             "start": 32271,
#             "end": 32272,
#             "tag": "PRP",
#             "pos": "PRON",
#             "morph": "PronType=Prs",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5850,
#             "start": 32272,
#             "end": 32273,
#             "tag": "PRP",
#             "pos": "PRON",
#             "morph": "PronType=Prs",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5851,
#             "start": 32273,
#             "end": 32276,
#             "tag": "_SP",
#             "pos": "SPACE",
#             "morph": "",
#             "lemma": "\n\n\n",
#             "dep": "dep",
#             "head": 5850
#         },
#         {
#             "id": 5852,
#             "start": 32276,
#             "end": 32277,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "=",
#             "dep": "nmod",
#             "head": 5854
#         },
#         {
#             "id": 5853,
#             "start": 32277,
#             "end": 32278,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "=",
#             "dep": "compound",
#             "head": 5854
#         },
#         {
#             "id": 5854,
#             "start": 32279,
#             "end": 32289,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "reference",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5855,
#             "start": 32290,
#             "end": 32291,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5856,
#             "start": 32291,
#             "end": 32292,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5857,
#             "start": 32292,
#             "end": 32295,
#             "tag": "_SP",
#             "pos": "SPACE",
#             "morph": "",
#             "lemma": "\n\n\n",
#             "dep": "dep",
#             "head": 5856
#         },
#         {
#             "id": 5858,
#             "start": 32295,
#             "end": 32296,
#             "tag": "VBP",
#             "pos": "VERB",
#             "morph": "Tense=Pres|VerbForm=Fin",
#             "lemma": "=",
#             "dep": "nsubj",
#             "head": 5859
#         },
#         {
#             "id": 5859,
#             "start": 32296,
#             "end": 32297,
#             "tag": "VBP",
#             "pos": "VERB",
#             "morph": "Tense=Pres|VerbForm=Fin",
#             "lemma": "=",
#             "dep": "ccomp",
#             "head": 5847
#         },
#         {
#             "id": 5860,
#             "start": 32298,
#             "end": 32305,
#             "tag": "RB",
#             "pos": "ADV",
#             "morph": "",
#             "lemma": "far",
#             "dep": "advmod",
#             "head": 5861
#         },
#         {
#             "id": 5861,
#             "start": 32306,
#             "end": 32313,
#             "tag": "VBG",
#             "pos": "VERB",
#             "morph": "Aspect=Prog|Tense=Pres|VerbForm=Part",
#             "lemma": "read",
#             "dep": "xcomp",
#             "head": 5859
#         },
#         {
#             "id": 5862,
#             "start": 32314,
#             "end": 32315,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5861
#         },
#         {
#             "id": 5863,
#             "start": 32315,
#             "end": 32316,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "=",
#             "dep": "punct",
#             "head": 5847
#         },
#         {
#             "id": 5864,
#             "start": 32316,
#             "end": 32319,
#             "tag": "_SP",
#             "pos": "SPACE",
#             "morph": "",
#             "lemma": "\n\n\n",
#             "dep": "dep",
#             "head": 5863
#         },
#         {
#             "id": 5865,
#             "start": 32319,
#             "end": 32320,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "=",
#             "dep": "ccomp",
#             "head": 5847
#         },
#         {
#             "id": 5866,
#             "start": 32320,
#             "end": 32321,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "=",
#             "dep": "amod",
#             "head": 5868
#         },
#         {
#             "id": 5867,
#             "start": 32322,
#             "end": 32330,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "external",
#             "dep": "amod",
#             "head": 5868
#         },
#         {
#             "id": 5868,
#             "start": 32331,
#             "end": 32336,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "link",
#             "dep": "ccomp",
#             "head": 5847
#         },
#         {
#             "id": 5869,
#             "start": 32337,
#             "end": 32338,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5870,
#             "start": 32338,
#             "end": 32339,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "=",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5871,
#             "start": 32339,
#             "end": 32341,
#             "tag": "_SP",
#             "pos": "SPACE",
#             "morph": "",
#             "lemma": "\n ",
#             "dep": "dep",
#             "head": 5870
#         },
#         {
#             "id": 5872,
#             "start": 32341,
#             "end": 32346,
#             "tag": "NNS",
#             "pos": "NOUN",
#             "morph": "Number=Plur",
#             "lemma": "medium",
#             "dep": "dobj",
#             "head": 5847
#         },
#         {
#             "id": 5873,
#             "start": 32347,
#             "end": 32354,
#             "tag": "VBN",
#             "pos": "VERB",
#             "morph": "Aspect=Perf|Tense=Past|VerbForm=Part",
#             "lemma": "relate",
#             "dep": "acl",
#             "head": 5872
#         },
#         {
#             "id": 5874,
#             "start": 32355,
#             "end": 32357,
#             "tag": "IN",
#             "pos": "ADP",
#             "morph": "",
#             "lemma": "to",
#             "dep": "prep",
#             "head": 5873
#         },
#         {
#             "id": 5875,
#             "start": 32358,
#             "end": 32365,
#             "tag": "JJ",
#             "pos": "ADJ",
#             "morph": "Degree=Pos",
#             "lemma": "natural",
#             "dep": "amod",
#             "head": 5876
#         },
#         {
#             "id": 5876,
#             "start": 32366,
#             "end": 32374,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "language",
#             "dep": "compound",
#             "head": 5877
#         },
#         {
#             "id": 5877,
#             "start": 32375,
#             "end": 32385,
#             "tag": "NN",
#             "pos": "NOUN",
#             "morph": "Number=Sing",
#             "lemma": "processing",
#             "dep": "pobj",
#             "head": 5874
#         },
#         {
#             "id": 5878,
#             "start": 32386,
#             "end": 32388,
#             "tag": "IN",
#             "pos": "ADP",
#             "morph": "",
#             "lemma": "at",
#             "dep": "prep",
#             "head": 5877
#         },
#         {
#             "id": 5879,
#             "start": 32389,
#             "end": 32398,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "Wikimedia",
#             "dep": "compound",
#             "head": 5880
#         },
#         {
#             "id": 5880,
#             "start": 32399,
#             "end": 32406,
#             "tag": "NNP",
#             "pos": "PROPN",
#             "morph": "Number=Sing",
#             "lemma": "Commons",
#             "dep": "pobj",
#             "head": 5878
#         }
#     ]
# }
# ('Natural', 'ADJ/amod', language)

# %%
# Defining functions:
def extract_syntax(doc):
  output = []
  for token in doc:
    output.append((token.text, token.pos_ + '/' + token.dep_, token.head.text))
    return output

extract_syntax(doc)

def extract_subjects(doc):
  output = []
  for token in doc:
    if token.dep_ == 'nsubj':
      output.append((token.text, token.head.text))
      return output

extract_subjects(doc)
# Out:
# [('processing', 'is')]

# %%
# Defining the pipeline:
def pipeline(text, nlp):
  doc = nlp(text)
  output = doc.to_json()
  output['syntax'] = extract_syntax(doc)
  output['subjects'] = extract_subjects(doc)
  return output

pipeline('Natural Language Processing is a sub-area of ​​artificial intelligence.', nlp)
# Out:
# {'text': 'Natural Language Processing is a sub-area of \u200b\u200bartificial intelligence.',
#  'ents': [{'start': 0, 'end': 27, 'label': 'ORG'}],
#  'sents': [{'start': 0, 'end': 71}],
#  'tokens': [{'id': 0,
#    'start': 0,
#    'end': 7,
#    'tag': 'NNP',
#    'pos': 'PROPN',
#    'morph': 'Number=Sing',
#    'lemma': 'Natural',
#    'dep': 'compound',
#    'head': 1},
#   {'id': 1,
#    'start': 8,
#    'end': 16,
#    'tag': 'NNP',
#    'pos': 'PROPN',
#    'morph': 'Number=Sing',
#    'lemma': 'Language',
#    'dep': 'compound',
#    'head': 2},
#   {'id': 2,
#    'start': 17,
#    'end': 27,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'processing',
#    'dep': 'nsubj',
#    'head': 3},
#   {'id': 3,
#    'start': 28,
#    'end': 30,
#    'tag': 'VBZ',
#    'pos': 'AUX',
#    'morph': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'lemma': 'be',
#    'dep': 'ROOT',
#    'head': 3},
#   {'id': 4,
#    'start': 31,
#    'end': 32,
#    'tag': 'DT',
#    'pos': 'DET',
#    'morph': 'Definite=Ind|PronType=Art',
#    'lemma': 'a',
#    'dep': 'det',
#    'head': 5},
#   {'id': 5,
#    'start': 33,
#    'end': 36,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'sub',
#    'dep': 'attr',
#    'head': 3},
#   {'id': 6,
#    'start': 36,
#    'end': 37,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': '-',
#    'dep': 'attr',
#    'head': 3},
#   {'id': 7,
#    'start': 37,
#    'end': 41,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'area',
#    'dep': 'attr',
#    'head': 3},
#   {'id': 8,
#    'start': 42,
#    'end': 44,
#    'tag': 'IN',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'of',
#    'dep': 'prep',
#    'head': 7},
#   {'id': 9,
#    'start': 45,
#    'end': 57,
#    'tag': 'JJ',
#    'pos': 'ADJ',
#    'morph': 'Degree=Pos',
#    'lemma': '\u200b\u200bartificial',
#    'dep': 'amod',
#    'head': 10},
#   {'id': 10,
#    'start': 58,
#    'end': 70,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'intelligence',
#    'dep': 'pobj',
#    'head': 8},
#   {'id': 11,
#    'start': 70,
#    'end': 71,
#    'tag': '.',
#    'pos': 'PUNCT',
#    'morph': 'PunctType=Peri',
#    'lemma': '.',
#    'dep': 'punct',
#    'head': 3}],
#  'syntax': [('Natural', 'PROPN/compound', 'Language')],
#  'subjects': [('Processing', 'is')]}

# %%
# Creating folders and log file:
if not os.path.isdir('raw_texts'):
  os.mkdir('raw_texts')

if not os.path.isdir('processed_texts'):
  os.mkdir('processed_texts')

log_file = open('log.txt', 'a')

# %%
# Extracting documents:
pages = []
for letter in 'abcdefghijklmnopqrstuvwxyz':
  pages.extend(wikipedia.search(letter, results=5))

len(pages)
pages
uuid.uuid4()

for page in tqdm.tqdm(pages):
  try:
    text = wikipedia.page(page).content
  except wikipedia.DisambiguationError:
    log_file.write(f'[{str(datetime.datetime.now())}] DisambiguationError: {page}\n')
  except wikipedia.PageError:
    log_file.write(f'[{str(datetime.datetime.now())}] PageError: {page}\n')
  else:
    with open(f'raw_texts/{uuid.uuid4()}.txt', 'w') as f:
      f.write(text)
      log_file.write(f'[{str(datetime.datetime.now())}] OK: {page}\n')
len(os.listdir('raw_texts'))
# Out:
#  53%|█████▎    | 69/130 [00:54<00:48,  1.26it/s]/usr/local/lib/python3.12/dist-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /usr/local/lib/python3.12/dist-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# 100%|██████████| 130/130 [01:43<00:00,  1.25it/s]
# 121

# %%
# Transforming and storing documents:
nlp = spacy.load('en_core_web_sm')

for file in tqdm.tqdm(os.listdir('raw_texts')):
  with open('raw_texts/' + file) as f:
    text= f.read()

    processed = pipeline(text, nlp)
    timestamp = str(datetime.datetime.now())
    processed['timestamp'] = timestamp
    log_file.write(f"[{str(datetime.datetime.now())}] Pipeline: {file}\n")

    with open('processed_texts/' + file + '.json', 'w') as f:
      json.dump(processed, f)

    os.remove('raw_texts/' + file)

log_file.close()
# Out:
# 100%|██████████| 121/121 [01:21<00:00,  1.48it/s]
