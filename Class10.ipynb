# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/NaturalLanguageProcessing/blob/main/Class10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Natural Language with NLTK**
# The Natural Language Toolkit (NLTK) is a versatile and powerful Python library for Natural Language Processing, offering tools that range from basic text processing, such as tokenization and syntactic analysis, to advanced tasks like sentiment analysis and text classification. Its flexibility and rich set of linguistic resources make it especially suitable for research and education, supported by an active community. NLTK enables practical text analysis, including the exploration of literary corpora like the works of Machado de Assis, where users can examine word frequencies, collocations, and concordances. Additionally, the library supports machine learning applications, such as training classification models using datasets like MacMorpho, with careful feature extraction and algorithm selection playing key roles. Through evaluation, error analysis, and the use of contextual features, NLTK allows continuous model improvement, making it a comprehensive solution for analyzing and modeling natural language.

# %%
# Importing all the necessary libraries and resources:
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import machado
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.corpus import floresta
import string

# %% [markdown]
# ## **Example: Sentiment Analysis with NLTK**
# The following example demonstrates the practical application of NLTK in a common NLP task, showcasing its usefulness and ease of use. In short, NLTK is a powerful tool that offers numerous functionalities for exploring the complexity of human language, making it a valuable choice for academics and professionals in the field of NLP.

# %%
# Downloading the necessary resources:
nltk.download('vader_lexicon')

# Inicializing the sentiment analyzer:
sia = SentimentIntensityAnalyzer()

# Example text:
text = 'NLTK is an excellent tool for those studying natural language processing.'

# Sentiment analysis:
sentiment = sia.polarity_scores(text)
print('Sentiment analysis', sentiment)
# Out:
# Sentiment analysis {'neg': 0.0, 'neu': 0.592, 'pos': 0.408, 'compound': 0.7351}
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## **Example: Frequency Analysis with NLTK**
# This example demonstrates not only how to use NLTK to manipulate and analyze literary texts, but also illustrates the potential of this library to enrich the understanding of classic works through technology. The next step will involve training a language model using NLTK, further exploring the capabilities of this tool in our study of natural language processing.

# %%
import nltk
from nltk.corpus import machado
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
import os

nltk.download('machado')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# Construct the full path to the machado corpus file
# NLTK data usually resides in nltk.data.path[0] (e.g., '/root/nltk_data')
# The machado corpus files are typically in 'corpora/machado/romances/'
machado_base_path = os.path.join(nltk.data.path[0], 'corpora', 'machado')
file_id = 'romances/marm08.txt' # This is the standard path within the corpus
full_file_path = os.path.join(machado_base_path, file_id)

# Loading the text by reading the file directly with utf-8 encoding
# This bypasses potential issues with the NLTK corpus reader's methods
with open(full_file_path, 'r', encoding='utf-8') as f:
    text = f.read()

# Tokenization:
tokens = word_tokenize(text, language='portuguese')

# Removing stopwords and punctuation:
stop_words = set(stopwords.words('portuguese') + list(string.punctuation))
clean_tokens = [token for token in tokens if token.lower() not in stop_words]

# Word frequency:
freq_dist = FreqDist(clean_tokens)

# Displaying the most frequent words:
freq_dist.plot(20)
# Out:
# Available file IDs in machado corpus:
# [nltk_data] Downloading package machado to /root/nltk_data...
# [nltk_data]   Package machado is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1253681994.py in <cell line: 0>()
#       7 # List all file identifiers in the machado corpus to determine the correct path
#       8 print("Available file IDs in machado corpus:")
# ----> 9 for fileid in machado.fileids():
#      10     print(fileid)
#      11
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/reader/api.py in fileids(self, categories)
#     379         """
#     380         if categories is None:
# --> 381             return super().fileids()
#     382         elif isinstance(categories, str):
#     383             if self._f2c is None:
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/reader/api.py in fileids(self)
# ...

# %% [markdown]
# ## **Example: Training a Classification Model Using NLTK**
# In this section, we show how to train a classification model to identify grammatical classes of words using the NLTK library. Understanding these classes is crucial for various applications in natural language processing, such as parsing and named entity recognition. Here we prepare the dataset and extract the necessary features. For example, the word "Jersey" is analyzed to check if it starts with a capital letter and to identify its most common suffixes. We use a Naive Bayes model to classify the words based on the extracted attributes. The dataset is divided into training and test parts to fairly and effectively evaluate the model's accuracy.

# %%
nltk.download('floresta')
tokens = floresta.tagged_words()
freq_suffixes = nltk.FreqDist([word[-3:] for word, tag in tokens if len(word) >= 3])
common_suffixes = [suffix for (suffix, count) in freq_suffixes.most_common(100)]

def features(word):
  return {'last_letter': word[-1], 'suffix1': word[-2:], 'suffix2': word[-3:]}

tagged_words = [(word, tag) for (word, tag) in tokens if len(word) >= 3]
featuresets = [(features(n), g) for (n, g) in tagged_words]
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# Evaluating the model:
accuracy = nltk.classify.accuracy(classifier, test_set)
print(f"Model accuracy: {accuracy:.2%}")
